# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from pandas import read_csv
from sklearn.preprocessing import LabelEncoder
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

import pandas as pd
from itertools import combinations
from statsmodels.tsa.vector_ar.vecm import coint_johansen
from statsmodels.tsa.api import VAR

#from keras.models import Sequential
#from keras.layers import Dense
#from keras.layers import LSTM

from numpy import concatenate
from pandas import DataFrame
from math import sqrt

# %%
# The path to our CSV file
file = "../data/csv/Gold_Data.csv"
df = pd.read_csv(file)
df.head()
# Out:
#               Business_Week  Gold_Change  Gold_Settle   Gold_Volume  \
# 0  [2006-06-07, 2006-06-13]          0.0       602.80    324.800000
# 1  [2006-06-14, 2006-06-20]          0.0       570.50     78.400000
# 2  [2006-06-21, 2006-06-27]          0.0       584.18     51.800000
# 3  [2006-06-28, 2006-07-04]          0.0       594.40  31923.666667
# 4  [2006-07-05, 2006-07-11]          0.0       634.00  43180.200000
#
#    Gold_Prev. Day Open Interest        Date  Open Interest  \
# 0                      189517.8  2006-06-13       382474.0
# 1                      191302.8  2006-06-20       390281.0
# 2                      189599.0  2006-06-27       384321.0
# 3                      297778.0  2006-07-03       392868.0
# 4                      253799.8  2006-07-11       427008.0
#
#    Money Manager Shorts  Money Manager Longs  Ten_Yr_Futures_Change  ...  \
# 0               30916.0             103211.0                    0.0  ...
# 1               30963.0              94632.0                    0.0  ...
# 2               32287.0              91042.0                    0.0  ...
# 3               30452.0              92545.0                    0.0  ...
# 4               27624.0             104213.0                    0.0  ...
#
#    USD_Change  USD_Settle  USD_Volume  USD_Wave  USD_Prev. Day Open Interest  \
# 0       1.760     85.7620      7364.2       NaN                      38753.4
# 1       0.013     86.2112       772.6       NaN                      37679.6
# 2       0.340     86.0000      5056.2       NaN                      23433.4
# 3      -1.300     85.2640      2935.2       NaN                      19682.8
# 4       0.230     85.0220      2823.0       NaN                      19415.6
#
#    ZAR_Change  ZAR_Settle  ZAR_Volume  ZAR_Wave  ZAR_Prev. Day Open Interest
# 0      0.0760      6.7790       65.00       NaN                      2332.40
# 1      0.1175      6.9283       45.00       NaN                      2276.80
# 2      0.1715      7.4125      359.25       NaN                      2395.75
# 3     -0.2920      7.1685       35.60       NaN                      2007.00
# 4      0.0960      7.1820      186.20       NaN                      2227.00
#
# [5 rows x 23 columns]

# %%
df = pd.read_csv("../data/csv/Gold_Data.csv",index_col="Business_Week")
print(len(df.columns),len(df.index))
# Out:
# 22 684

# %%
df = df.drop(df.columns[0],axis=1)
df = df.drop(df.columns[7],axis=1)
df = df.dropna(axis=1)
df = df.dropna()
print(len(df.columns),len(df.index))
# Out:
# 16 684

# %%
df.head()
# Out:
#                           Gold_Settle   Gold_Volume  \
# Business_Week
# [2006-06-07, 2006-06-13]       602.80    324.800000
# [2006-06-14, 2006-06-20]       570.50     78.400000
# [2006-06-21, 2006-06-27]       584.18     51.800000
# [2006-06-28, 2006-07-04]       594.40  31923.666667
# [2006-07-05, 2006-07-11]       634.00  43180.200000
#
#                           Gold_Prev. Day Open Interest        Date  \
# Business_Week
# [2006-06-07, 2006-06-13]                      189517.8  2006-06-13
# [2006-06-14, 2006-06-20]                      191302.8  2006-06-20
# [2006-06-14, 2006-06-20]       390281.0               30963.0
# [2006-06-21, 2006-06-27]       384321.0               32287.0
# [2006-06-28, 2006-07-04]       392868.0               30452.0
# [2006-07-05, 2006-07-11]       427008.0               27624.0
#
#                           Money Manager Longs  Ten_Yr_Futures_Settle  \
# Business_Week
# [2006-06-07, 2006-06-13]             103211.0              105.86250
# [2006-06-14, 2006-06-20]              94632.0              105.01875
# [2006-06-21, 2006-06-27]              91042.0              104.33125
# [2006-06-28, 2006-07-04]              92545.0              104.53125
# [2006-07-05, 2006-07-11]             104213.0              104.71250
#
#                           Ten_Yr_Futures_Volume  \
# Business_Week
# [2006-06-07, 2006-06-13]                34971.6
# [2006-06-14, 2006-06-20]                10278.8
# [2006-06-21, 2006-06-27]               547949.0
# [2006-06-28, 2006-07-04]               663508.5
# [2006-07-05, 2006-07-11]               791971.0
#
#                           Ten_Yr_Futures_Prev. Day Open Interest  USD_Change  \
# Business_Week
# [2006-06-07, 2006-06-13]                              1935826.00       1.760
# [2006-06-14, 2006-06-20]                              2003874.80       0.013
# [2006-06-21, 2006-06-27]                              2151127.00       0.340
# [2006-06-28, 2006-07-04]                              2168869.75      -1.300
# [2006-07-05, 2006-07-11]                              2154420.80       0.230
#
#                           USD_Settle  USD_Volume  USD_Prev. Day Open Interest  \
# Business_Week
# [2006-06-07, 2006-06-13]     85.7620      7364.2                      38753.4
# [2006-06-14, 2006-06-20]     86.2112       772.6                      37679.6
# [2006-06-21, 2006-06-27]     86.0000      5056.2                      23433.4
# [2006-06-28, 2006-07-04]     85.2640      2935.2                      19682.8
# [2006-07-05, 2006-07-11]     85.0220      2823.0                      19415.6
#
#                           ZAR_Change  ZAR_Settle
# Business_Week
# [2006-06-07, 2006-06-13]      0.0760      6.7790
# [2006-06-14, 2006-06-20]      0.1175      6.9283
# [2006-06-21, 2006-06-27]      0.1715      7.4125
# [2006-06-28, 2006-07-04]     -0.2920      7.1685
# [2006-07-05, 2006-07-11]      0.0960      7.1820

# %%
X = data
y = target.values
print(X.shape, y.shape)
# Out:
# (684, 14) (684,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.svm import SVR 
model = SVR(kernel='linear')

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
grid.fit(X_train, y_train)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...... C=1, gamma=0.0001, score=-33083047.78888021, total= 1.4min
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.4min remaining:    0.0s
# [CV] ..... C=1, gamma=0.0001, score=-11228280.810819848, total= 3.9min
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  5.4min remaining:    0.0s
# [CV] ..... C=1, gamma=0.0001, score=-18385190.372987904, total= 1.3min
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....... C=1, gamma=0.001, score=-33083047.78888021, total= 1.4min
# [CV] C=1, gamma=0.001 ................................................
# [CV] ...... C=1, gamma=0.001, score=-11228280.810819848, total= 3.9min
# [CV] C=1, gamma=0.001 ................................................
# [CV] ...... C=1, gamma=0.001, score=-18385190.372987904, total= 1.3min
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........ C=1, gamma=0.01, score=-33083047.78888021, total= 1.4min
# [CV] C=1, gamma=0.01 .................................................
# [CV] ....... C=1, gamma=0.01, score=-11228280.810819848, total= 3.9min
# [CV] C=1, gamma=0.01 .................................................
# [CV] ....... C=1, gamma=0.01, score=-18385190.372987904, total= 1.3min
# [CV] C=5, gamma=0.0001 ...............................................

# %%
print(grid.best_params_)

# %%
print(grid.best_score_)

# %%
predictions = grid.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=["blue", "red"]))
